# %% [markdown]
# ## Part 1
#
# ### Data Processing

# %%
# imports

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
# Had to add encoding option, since the standard is in UTF-8, and our data was not

df = pd.read_csv('assignment_7_data_aml.txt', encoding = "ISO-8859-1")
df.dropna(subset = ["lat"])
# Out:
#                   address      zip_code    price   sell_date  sell_type  \
# oesterbro 22        2. TH  9000 Aalborg  1295000  30-10-2015  Alm. Salg
# oesterbro 24        1. TV  9000 Aalborg  2000000  23-10-2015  Alm. Salg
# oesterbro 24        3. TV  9000 Aalborg  1898000  27-04-2015  Alm. Salg
# oesterbro 29D       2. TH  9000 Aalborg  2945000  25-08-2015  Alm. Salg
# oesterbro 29E       2. TH  9000 Aalborg  2425000  24-09-2015  Alm. Salg
# ...                   ...           ...      ...         ...        ...
# Vingaardsgade 11    3. TV  9000 Aalborg  1340000  28-10-2015  Alm. Salg
# Vingaardsgade 27    4. TV  9000 Aalborg  1750000  05-02-2015  Alm. Salg
# Vingaardsgade 32    2. TH  9000 Aalborg  1160000  23-04-2015  Alm. Salg
# Vingaardsgade 4     3. TH  9000 Aalborg  1615000  08-10-2015  Alm. Salg
# Willemoesgade 5    ST. TV  9000 Aalborg  1150000  12-11-2015  Alm. Salg
#
#                   price_per_sq_m no_rooms housing_type  size_in_sq_m  \
# oesterbro 22              185000       20    Lejlighed           700
# oesterbro 24              186910       40    Lejlighed          1070
# oesterbro 24              186070       40    Lejlighed          1020
# oesterbro 29D             239430       30    Lejlighed          1230
# oesterbro 29E             247440       30    Lejlighed           980
# ...                          ...      ...          ...           ...
# Vingaardsgade 11          188730       20    Lejlighed           710
# Vingaardsgade 27          147050       30    Lejlighed          1190
# Vingaardsgade 32          175750       20    Lejlighed           660
# Vingaardsgade 4           209740       20    Lejlighed           770
# Willemoesgade 5           191660       20    Lejlighed           600
#
#                   year_of_construction  price_change_in_pct  zip_code_num  \
# oesterbro 22                     19000                    0          9000
# oesterbro 24                     19280                    0          9000
# oesterbro 24                     19280                    0          9000
# oesterbro 29D                    20130                  -20          9000
# oesterbro 29E                    20130                  -30          9000
# ...                                ...                  ...           ...
# Vingaardsgade 11                 19380                    0          9000
# Vingaardsgade 27                 19270                  -30          9000
# Vingaardsgade 32                 19310                  -30          9000
# Vingaardsgade 4                  19380                    0          9000
# Willemoesgade 5                  19340                    0          9000
#
#                      long         lat
# oesterbro 22      9933196  57046009.0
# oesterbro 24      9934895  57045929.0
# oesterbro 24      9934895  57045929.0
# oesterbro 29D     9936365  57046424.0
# oesterbro 29E     9936407  57046491.0
# ...                   ...         ...
# Vingaardsgade 11  9918029   5704703.0
# Vingaardsgade 27  9915715  57047735.0
# Vingaardsgade 32  9915987  57047822.0
# Vingaardsgade 4   9919094  57046892.0
# Willemoesgade 5   9899607  57054955.0
#
# [414 rows x 14 columns]

# %%
# Need label encoding since it gives cannot convert string to float error otherwise

le = LabelEncoder()
df['zip_code_float'] = le.fit_transform(df['zip_code'])

# %% [markdown]
# ### Data
#
# In the data we have deleted random rows and outliers, and replaced æøå characters with standard english keyboard characters.

# %%
df.head()
# Out:
#               address      zip_code    price   sell_date  sell_type  \
# oesterbro 22    2. TH  9000 Aalborg  1295000  30-10-2015  Alm. Salg
# oesterbro 24    1. TV  9000 Aalborg  2000000  23-10-2015  Alm. Salg
# oesterbro 24    3. TV  9000 Aalborg  1898000  27-04-2015  Alm. Salg
# oesterbro 29D   2. TH  9000 Aalborg  2945000  25-08-2015  Alm. Salg
# oesterbro 29E   2. TH  9000 Aalborg  2425000  24-09-2015  Alm. Salg
#
#                price_per_sq_m no_rooms housing_type  size_in_sq_m  \
# oesterbro 22           185000       20    Lejlighed           700
# oesterbro 24           186910       40    Lejlighed          1070
# oesterbro 24           186070       40    Lejlighed          1020
# oesterbro 29D          239430       30    Lejlighed          1230
# oesterbro 29E          247440       30    Lejlighed           980
#
#                year_of_construction  price_change_in_pct  zip_code_num  \
# oesterbro 22                  19000                    0          9000
# oesterbro 24                  19280                    0          9000
# oesterbro 24                  19280                    0          9000
# oesterbro 29D                 20130                  -20          9000
# oesterbro 29E                 20130                  -30          9000
#
#                   long         lat  zip_code_float
# oesterbro 22   9933196  57046009.0             146
# oesterbro 24   9934895  57045929.0             146
# oesterbro 24   9934895  57045929.0             146
# oesterbro 29D  9936365  57046424.0             146
# oesterbro 29E  9936407  57046491.0             146

# %% [markdown]
# ## Part 2
#
# ### ML Model Selection and Construction
#
# After taking a look at the data we can see that there is a column "price_change_in_pct". This column can be used to predict the change in the value, by labeling them so that a Classification model can use it.
#
# We were considering using either the KNN or the DecisionTreeClassifier, because the goal is to partition the data in subsets, where they are either adjusted or not adjusted.
#
# We decided that the DecisionTreeClassifier is a viable option for this use case, using a Divide-and-Conquer approach, where we can create a branch, split instances into subsets and apply recursion.

# %%
# we can see that we get various values for the price change in pct, therefore we need to create labels for these.
pd.set_option('display.max_rows', 10)

df['price_change_in_pct']
# Out:
# oesterbro 22           0
# oesterbro 24           0
# oesterbro 24           0
# oesterbro 29D        -20
# oesterbro 29E        -30
#                     ...
# Vingaardsgade 32     -30
# Vingaardsgade 4        0
# Vonsyldsgade 17     9000
# Vonsyldsgade 37     9000
# Willemoesgade 5        0
# Name: price_change_in_pct, Length: 610, dtype: int64

# %% [markdown]
# #### labeling the price change
#
# To simplify the data we assign
#
#     - 0 price decrease
#     - 1 price static
#     - 2 price increase

# %%
def labeled_price_pct(price):
    if(price) < 0:
        return 0
    if(price) > 0:
        return 2
    else :
        return 1

# %%
df['labeled_price_pct'] = df.apply(lambda x : labeled_price_pct(x['price_change_in_pct']), axis = 1)

# %%
df['labeled_price_pct']
# Out:
# oesterbro 22        1
# oesterbro 24        1
# oesterbro 24        1
# oesterbro 29D       0
# oesterbro 29E       0
#                    ..
# Vingaardsgade 32    0
# Vingaardsgade 4     1
# Vonsyldsgade 17     2
# Vonsyldsgade 37     2
# Willemoesgade 5     1
# Name: labeled_price_pct, Length: 610, dtype: int64

# %%
# not too much data as we can see....
df.labeled_price_pct.value_counts()
# Out:
# 2    217
# 0    205
# 1    188
# Name: labeled_price_pct, dtype: int64

# %%
# Masking & balancing

m_0 = df[df['labeled_price_pct'] == 0]
m_1 = df[df['labeled_price_pct'] == 1]
m_2 = df[df['labeled_price_pct'] == 2]

b_0 = m_0[:188]
b_2 = m_2[:188]

balanced_data = pd.concat([b_0, m_1, b_2], axis = 0)

balanced_data.dropna()
# Out:
#                       address      zip_code    price   sell_date  sell_type  \
# oesterbro 29D           2. TH  9000 Aalborg  2945000  25-08-2015  Alm. Salg
# oesterbro 29E           2. TH  9000 Aalborg  2425000  24-09-2015  Alm. Salg
# oesterbro 57           ST. TV  9000 Aalborg   970000  23-02-2015  Alm. Salg
# oestergravensgade 12   ST. TH  9000 Aalborg  1130000  03-06-2015  Alm. Salg
# oestre Alle 11              1  9000 Aalborg  1500000  11-06-2015  Alm. Salg
# ...                       ...           ...      ...         ...        ...
# Malurtvej 29            1. TV  9000 Aalborg  1245000  12-04-2015  Alm. Salg
# Nybrogade 4             1. MF  9000 Aalborg  1486000  15-04-2015  Alm. Salg
# Poul Paghs Gade 6B      1. TH  9000 Aalborg  1216000  17-06-2015  Alm. Salg
# Ryesgade 49             2. TH  9000 Aalborg   950000  28-01-2015  Alm. Salg
# Snerlevej 1             2. TH  9000 Aalborg  1400000  15-07-2015  Alm. Salg
#
#                       price_per_sq_m no_rooms housing_type  size_in_sq_m  \
# oesterbro 29D                 239430       30    Lejlighed          1230
# oesterbro 29E                 247440       30    Lejlighed           980
# oesterbro 57                  151560       20    Lejlighed           640
# oestergravensgade 12          198240       20    Lejlighed           570
# oestre Alle 11                166660       20    Lejlighed           900
# ...                              ...      ...          ...           ...
# Malurtvej 29                  168240       30    Lejlighed           740
# Nybrogade 4                   206380       20    Lejlighed           720
# Poul Paghs Gade 6B            181490       20    Lejlighed           670
# Ryesgade 49                   175920       20    Lejlighed           540
# Snerlevej 1                   159090       40    Lejlighed           880
#
#                       year_of_construction  price_change_in_pct  zip_code_num  \
# oesterbro 29D                        20130                  -20          9000
# oesterbro 29E                        20130                  -30          9000
# oesterbro 57                         19340                  -30          9000
# oestergravensgade 12                 18890                  -40          9000
# oestre Alle 11                       19200                  -30          9000
# ...                                    ...                  ...           ...
# Malurtvej 29                         19710                   20          9000
# Nybrogade 4                          19960                   20          9000
# Poul Paghs Gade 6B                   19020                   20          9000
# Ryesgade 49                          19280                   60          9000
# Snerlevej 1                          19580                   30          9000
#
#                          long         lat  zip_code_float  labeled_price_pct
# oesterbro 29D         9936365  57046424.0             146                  0
# oesterbro 29E         9936407  57046491.0             146                  0
# oesterbro 57          9941545  57045841.0             146                  0
# oestergravensgade 12  9927859  57045956.0             146                  0
# oestre Alle 11        9947868  57043636.0             146                  0
# ...                       ...         ...             ...                ...
# Malurtvej 29          9899402  57024315.0             146                  2
# Nybrogade 4           9914724  57053653.0             146                  2
# Poul Paghs Gade 6B    9910862   5705156.0             146                  2
# Ryesgade 49            990288  57054005.0             146                  2
# Snerlevej 1           9906422  57034079.0             146                  2
#
# [394 rows x 16 columns]

# %%
X = balanced_data[['price_per_sq_m','size_in_sq_m']]
y = balanced_data.labeled_price_pct

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1,shuffle=True)

# %%
model = DecisionTreeClassifier(max_depth = 3)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
prediction = model.predict(X_test)
accuracy_score(y_test, prediction)
# Out:
# 0.7486631016042781

# %%
metrics.confusion_matrix(y_test, prediction)
# Out:
# array([[50, 11,  0],
#        [31, 24,  0],
#        [ 5,  0, 66]], dtype=int64)

# %% [markdown]
# ### Conclusion
#
# Not a very great solution,due to the lack of data
